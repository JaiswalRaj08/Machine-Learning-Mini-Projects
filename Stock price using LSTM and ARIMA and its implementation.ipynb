# %% [markdown]
# # Part 1

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# - Long short term memory (LSTM) is a model that increases the memory of recurrent neural networks.
#
# - Recurrent neural networks hold short term memory in that they allow earlier determining information to be employed in the current neural networks.
#
# - For immediate tasks, the earlier data is used. We may not possess a list of all of the earlier information for the neural node.
#
# - In RNNs, LSTMs are very widely used in Neural networks. Their effectiveness should be implemented to multiple sequence modelling problems in many application domains like video, NLP, geospatial, and time-series.
#
# - One of the main issues with RNN is the vanishing gradient problem, and it emerges due to the repeated use of the same parameters, in RNN blocks, at each step.
#
# - We must try to use different parameters to overcome this problem at each time step.We try to find a balance in such a situation. We bring novel parameters at each step while generalizing variable-length sequences and keeping the overall amount of learnable parameters constant. We introduce gated RNN cells like LSTM and GRU.
#
# - Gated cells hold internal variables, which are Gates. This value of each gate at each time step depends on the information at that time step, including early states.
#
# - The value of the gate then becomes multiplied by the different variables of interest to influence them. Time-series data is a series of data values gathered over time interims, allowing us to trace differences over time. Time-series data can trace progress over milliseconds, days, and years.
#
# - Early, our perspective of time-series data meant more static; the everyday highs and lows under temperature, the opening and closing amount of the stock market. Now we will go to the coding part. We will implement LSTM on the stocks dataset.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Dataset
#
# https://github.com/PacktPublishing/Learning-Pandas-Second-Edition/blob/master/data/goog.csv

# %% [markdown]
# # 3. Implementation of LSTM on Google stocks data

# %% [markdown]
# ## 3.1 Reading Data

# %%
google_stock_data = pd.read_csv(r'C:\Users\HOME\Desktop\GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ## 3.2 Data Viz
#
# We have performed a few feature extraction here. We take the dates alone from the overall date variable. Now we can be using matplotlib to visualize the available data and see how our price values in data are being displayed. The green colour was used to visualize the open variable for the price-date graph, and for the closing variable, we used red colour.

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %%
plt.figure(figsize = (15,8))
plt.plot(google_stock_data['high'])
plt.plot(google_stock_data['low'])
plt.legend(['High','Low'])
plt.title('High and Low Stock Prices, Google', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'High and Low Stock Prices, Google')

# %%
google_stock_data['high'].plot(figsize=(12,8))
plt.ylabel("High price")
# Out:
# Text(0, 0.5, 'High price')

# %%
google_stock_data['volume'].plot(figsize=(12,8))
plt.ylabel("Volume price")
# Out:
# Text(0, 0.5, 'Volume price')

# %% [markdown]
# ## 3.3 Exploring Dataset:
#
# The dataset contains 14 columns associated with time series like the date and the different variables like close, high, low and volume. We will use opening and closing values for our experimentation of time series with LSTM.

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
corr = google_stock_data.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_3b2a2_row0_col0, #T_3b2a2_row0_col1, #T_3b2a2_row0_col2, #T_3b2a2_row0_col3, #T_3b2a2_row0_col5, #T_3b2a2_row0_col6, #T_3b2a2_row0_col7, #T_3b2a2_row0_col8, #T_3b2a2_row1_col0, #T_3b2a2_row1_col1, #T_3b2a2_row1_col2, #T_3b2a2_row1_col3, #T_3b2a2_row1_col5, #T_3b2a2_row1_col6, #T_3b2a2_row1_col7, #T_3b2a2_row1_col8, #T_3b2a2_row2_col0, #T_3b2a2_row2_col1, #T_3b2a2_row2_col2, #T_3b2a2_row2_col3, #T_3b2a2_row2_col5, #T_3b2a2_row2_col6, #T_3b2a2_row2_col7, #T_3b2a2_row2_col8, #T_3b2a2_row3_col0, #T_3b2a2_row3_col1, #T_3b2a2_row3_col2, #T_3b2a2_row3_col3, #T_3b2a2_row3_col5, #T_3b2a2_row3_col6, #T_3b2a2_row3_col7, #T_3b2a2_row3_col8, #T_3b2a2_row4_col4, #T_3b2a2_row4_col9, #T_3b2a2_row5_col0, #T_3b2a2_row5_col1, #T_3b2a2_row5_col2, #T_3b2a2_row5_col3, #T_3b2a2_row5_col5, #T_3b2a2_row5_col6, #T_3b2a2_row5_col7, #T_3b2a2_row5_col8, #T_3b2a2_row6_col0, #T_3b2a2_row6_col1, #T_3b2a2_row6_col2, #T_3b2a2_row6_col3, #T_3b2a2_row6_col5, #T_3b2a2_row6_col6, #T_3b2a2_row6_col7, #T_3b2a2_row6_col8, #T_3b2a2_row7_col0, #T_3b2a2_row7_col1, #T_3b2a2_row7_col2, #T_3b2a2_row7_col3, #T_3b2a2_row7_col5, #T_3b2a2_row7_col6, #T_3b2a2_row7_col7, #T_3b2a2_row7_col8, #T_3b2a2_row8_col0, #T_3b2a2_row8_col1, #T_3b2a2_row8_col2, #T_3b2a2_row8_col3, #T_3b2a2_row8_col5, #T_3b2a2_row8_col6, #T_3b2a2_row8_col7, #T_3b2a2_row8_col8, #T_3b2a2_row9_col4, #T_3b2a2_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3b2a2_row0_col4, #T_3b2a2_row0_col9, #T_3b2a2_row5_col4, #T_3b2a2_row5_col9 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_3b2a2_row0_col10, #T_3b2a2_row0_col11, #T_3b2a2_row1_col10, #T_3b2a2_row1_col11, #T_3b2a2_row2_col10, #T_3b2a2_row2_col11, #T_3b2a2_row3_col10, #T_3b2a2_row3_col11, #T_3b2a2_row4_col10, #T_3b2a2_row4_col11, #T_3b2a2_row5_col10, #T_3b2a2_row5_col11, #T_3b2a2_row6_col10, #T_3b2a2_row6_col11, #T_3b2a2_row7_col10, #T_3b2a2_row7_col11, #T_3b2a2_row8_col10, #T_3b2a2_row8_col11, #T_3b2a2_row9_col10, #T_3b2a2_row9_col11, #T_3b2a2_row10_col0, #T_3b2a2_row10_col1, #T_3b2a2_row10_col2, #T_3b2a2_row10_col3, #T_3b2a2_row10_col4, #T_3b2a2_row10_col5, #T_3b2a2_row10_col6, #T_3b2a2_row10_col7, #T_3b2a2_row10_col8, #T_3b2a2_row10_col9, #T_3b2a2_row10_col10, #T_3b2a2_row10_col11, #T_3b2a2_row11_col0, #T_3b2a2_row11_col1, #T_3b2a2_row11_col2, #T_3b2a2_row11_col3, #T_3b2a2_row11_col4, #T_3b2a2_row11_col5, #T_3b2a2_row11_col6, #T_3b2a2_row11_col7, #T_3b2a2_row11_col8, #T_3b2a2_row11_col9, #T_3b2a2_row11_col10, #T_3b2a2_row11_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_3b2a2_row1_col4, #T_3b2a2_row1_col9, #T_3b2a2_row6_col4, #T_3b2a2_row6_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_3b2a2_row2_col4, #T_3b2a2_row2_col9, #T_3b2a2_row4_col0, #T_3b2a2_row4_col1, #T_3b2a2_row4_col2, #T_3b2a2_row4_col3, #T_3b2a2_row4_col5, #T_3b2a2_row4_col6, #T_3b2a2_row4_col7, #T_3b2a2_row4_col8, #T_3b2a2_row7_col4, #T_3b2a2_row7_col9, #T_3b2a2_row9_col0, #T_3b2a2_row9_col1, #T_3b2a2_row9_col2, #T_3b2a2_row9_col3, #T_3b2a2_row9_col5, #T_3b2a2_row9_col6, #T_3b2a2_row9_col7, #T_3b2a2_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_3b2a2_row3_col4, #T_3b2a2_row3_col9, #T_3b2a2_row8_col4, #T_3b2a2_row8_col9 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3b2a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b2a2_level0_col0" class="col_heading level0 col0" >close</th>
#       <th id="T_3b2a2_level0_col1" class="col_heading level0 col1" >high</th>
#       <th id="T_3b2a2_level0_col2" class="col_heading level0 col2" >low</th>
#       <th id="T_3b2a2_level0_col3" class="col_heading level0 col3" >open</th>
#       <th id="T_3b2a2_level0_col4" class="col_heading level0 col4" >volume</th>
#       <th id="T_3b2a2_level0_col5" class="col_heading level0 col5" >adjClose</th>
#       <th id="T_3b2a2_level0_col6" class="col_heading level0 col6" >adjHigh</th>
#       <th id="T_3b2a2_level0_col7" class="col_heading level0 col7" >adjLow</th>
#       <th id="T_3b2a2_level0_col8" class="col_heading level0 col8" >adjOpen</th>
#       <th id="T_3b2a2_level0_col9" class="col_heading level0 col9" >adjVolume</th>
#       <th id="T_3b2a2_level0_col10" class="col_heading level0 col10" >divCash</th>
#       <th id="T_3b2a2_level0_col11" class="col_heading level0 col11" >splitFactor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b2a2_level0_row0" class="row_heading level0 row0" >close</th>
#       <td id="T_3b2a2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3b2a2_row0_col1" class="data row0 col1" >0.999528</td>
#       <td id="T_3b2a2_row0_col2" class="data row0 col2" >0.999586</td>
#       <td id="T_3b2a2_row0_col3" class="data row0 col3" >0.999083</td>
#       <td id="T_3b2a2_row0_col4" class="data row0 col4" >-0.025574</td>
#       <td id="T_3b2a2_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_3b2a2_row0_col6" class="data row0 col6" >0.999528</td>
#       <td id="T_3b2a2_row0_col7" class="data row0 col7" >0.999586</td>
#       <td id="T_3b2a2_row0_col8" class="data row0 col8" >0.999083</td>
#       <td id="T_3b2a2_row0_col9" class="data row0 col9" >-0.025574</td>
#       <td id="T_3b2a2_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_3b2a2_row0_col11" class="data row0 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3b2a2_level0_row1" class="row_heading level0 row1" >high</th>
#       <td id="T_3b2a2_row1_col0" class="data row1 col0" >0.999528</td>
#       <td id="T_3b2a2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3b2a2_row1_col2" class="data row1 col2" >0.999354</td>
#       <td id="T_3b2a2_row1_col3" class="data row1 col3" >0.999575</td>
#       <td id="T_3b2a2_row1_col4" class="data row1 col4" >-0.012470</td>
#       <td id="T_3b2a2_row1_col5" class="data row1 col5" >0.999528</td>
#       <td id="T_3b2a2_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_3b2a2_row1_col7" class="data row1 col7" >0.999354</td>
#       <td id="T_3b2a2_row1_col8" class="data row1 col8" >0.999575</td>
#       <td id="T_3b2a2_row1_col9" class="data row1 col9" >-0.012470</td>
#       <td id="T_3b2a2_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_3b2a2_row1_col11" class="data row1 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3b2a2_level0_row2" class="row_heading level0 row2" >low</th>
#       <td id="T_3b2a2_row2_col0" class="data row2 col0" >0.999586</td>
#       <td id="T_3b2a2_row2_col1" class="data row2 col1" >0.999354</td>
#       <td id="T_3b2a2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3b2a2_row2_col3" class="data row2 col3" >0.999499</td>
#       <td id="T_3b2a2_row2_col4" class="data row2 col4" >-0.035184</td>
#       <td id="T_3b2a2_row2_col5" class="data row2 col5" >0.999586</td>
#       <td id="T_3b2a2_row2_col6" class="data row2 col6" >0.999354</td>
#       <td id="T_3b2a2_row2_col7" class="data row2 col7" >1.000000</td>
#       <td id="T_3b2a2_row2_col8" class="data row2 col8" >0.999499</td>
#       <td id="T_3b2a2_row2_col9" class="data row2 col9" >-0.035184</td>
#       <td id="T_3b2a2_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_3b2a2_row2_col11" class="data row2 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3b2a2_level0_row3" class="row_heading level0 row3" >open</th>
#       <td id="T_3b2a2_row3_col0" class="data row3 col0" >0.999083</td>
#       <td id="T_3b2a2_row3_col1" class="data row3 col1" >0.999575</td>
#       <td id="T_3b2a2_row3_col2" class="data row3 col2" >0.999499</td>
#       <td id="T_3b2a2_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3b2a2_row3_col4" class="data row3 col4" >-0.021381</td>
#       <td id="T_3b2a2_row3_col5" class="data row3 col5" >0.999083</td>
#       <td id="T_3b2a2_row3_col6" class="data row3 col6" >0.999575</td>
#       <td id="T_3b2a2_row3_col7" class="data row3 col7" >0.999499</td>
#       <td id="T_3b2a2_row3_col8" class="data row3 col8" >1.000000</td>
#       <td id="T_3b2a2_row3_col9" class="data row3 col9" >-0.021381</td>
#       <td id="T_3b2a2

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %% [markdown]
# ## 3.4 Data Pre-Processing

# %% [markdown]
# We must pre-process this data before applying stock price using LSTM. Transform the values in our data with help of the fit_transform function. Min-max scaler is used for scaling the data so that we can bring all the price values to a common scale. We then use 80 % data for training and the rest 20% for testing and assign them to separate variables.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %% [markdown]
# ## 3.5 Splitting data for training:

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# ## 3.6 Implementation of our LSTM model:

# %% [markdown]
# In the next step, we create our LSTM model.  In this notebook, we will use the Sequential model imported from Keras and required libraries are imported.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %% [markdown]
# We use two LSTM layers in our model and implement drop out in between for regularization. The number of units assigned in the LSTM parameter is fifty. with a dropout of 10 %. Mean squared error is the loss function for optimizing the problem with adam optimizer. Mean absolute error is the metric used in our LSTM network as it is associated with time-series data

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 5s 51ms/step - loss: 0.0097 - mean_absolute_error: 0.0695 - val_loss: 0.0226 - val_mean_absolute_error: 0.1335
# Epoch 2/80
# 30/30 [==============================] - 1s 20ms/step - loss: 8.8566e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0043 - val_mean_absolute_error: 0.0533
# Epoch 3/80
# 30/30 [==============================] - 1s 21ms/step - loss: 5.1180e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 4/80
# 30/30 [==============================] - 1s 20ms/step - loss: 5.0412e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0041 - val_mean_absolute_error: 0.0515
# Epoch 5/80
# 30/30 [==============================] - 1s 19ms/step - loss: 5.2038e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0027 - val_mean_absolute_error: 0.0408
# Epoch 6/80
# 30/30 [==============================] - 1s 20ms/step - loss: 4.5212e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0024 - val_mean_absolute_error: 0.0389
# Epoch 7/80
# 30/30 [==============================] - 1s 20ms/step - loss: 4.3499e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0036 - val_mean_absolute_error: 0.0488
# Epoch 8/80
# 30/30 [==============================] - 1s 20ms/step - loss: 4.2272e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0024 - val_mean_absolute_error: 0.0382
# Epoch 9/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.9138e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0024 - val_mean_absolute_error: 0.0383
# Epoch 10/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.8927e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 11/80
# 30/30 [==============================] - 1s 19ms/step - loss: 3.8060e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0040 - val_mean_absolute_error: 0.0517
# Epoch 12/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.4849e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0064 - val_mean_absolute_error: 0.0680
# Epoch 13/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.5486e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0056 - val_mean_absolute_error: 0.0618
# Epoch 14/80
# 30/30 [==============================] - 1s 19ms/step - loss: 3.6673e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0072 - val_mean_absolute_error: 0.0716
# Epoch 15/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.4860e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0080 - val_mean_absolute_error: 0.0762
# Epoch 16/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.3815e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0069 - val_mean_absolute_error: 0.0702
# Epoch 17/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.1598e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0085 - val_mean_absolute_error: 0.0787
# Epoch 18/80
# 30/30 [==============================] - 1s 20ms/step - loss: 3.1799e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0083 - val_mean_absolute_error: 0.0774
# Epoch 19/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.9746e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0072 - val_mean_absolute_error: 0.0712
# Epoch 20/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.9670e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0070 - val_mean_absolute_error: 0.0702
# Epoch 21/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.8652e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0054 - val_mean_absolute_error: 0.0602
# Epoch 22/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.9460e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0064 - val_mean_absolute_error: 0.0666
# Epoch 23/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.8175e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0058 - val_mean_absolute_error: 0.0618
# Epoch 24/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.9797e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0039 - val_mean_absolute_error: 0.0500
# Epoch 25/80
# 30/30 [==============================] - 1s 19ms/step - loss: 3.1465e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0033 - val_mean_absolute_error: 0.0447
# Epoch 26/80
# 30/30 [==============================] - 1s 21ms/step - loss: 2.8774e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0070 - val_mean_absolute_error: 0.0706
# Epoch 27/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.8219e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0054 - val_mean_absolute_error: 0.0601
# Epoch 28/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.5764e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0059 - val_mean_absolute_error: 0.0629
# Epoch 29/80
# 30/30 [==============================] - 1s 21ms/step - loss: 2.5033e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0043 - val_mean_absolute_error: 0.0523
# Epoch 30/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.5131e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0037 - val_mean_absolute_error: 0.0485
# Epoch 31/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.4483e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0063 - val_mean_absolute_error: 0.0665
# Epoch 32/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.8375e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0091 - val_mean_absolute_error: 0.0811
# Epoch 33/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.6261e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0035 - val_mean_absolute_error: 0.0461
# Epoch 34/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.4009e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0042 - val_mean_absolute_error: 0.0513
# Epoch 35/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.6871e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0034 - val_mean_absolute_error: 0.0449
# Epoch 36/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.4733e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0040 - val_mean_absolute_error: 0.0506
# Epoch 37/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.1694e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0039 - val_mean_absolute_error: 0.0499
# Epoch 38/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.1937e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0054 - val_mean_absolute_error: 0.0603
# Epoch 39/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.3482e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0041 - val_mean_absolute_error: 0.0518
# Epoch 40/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.2257e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0032 - val_mean_absolute_error: 0.0454
# Epoch 41/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.1287e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0054 - val_mean_absolute_error: 0.0626
# Epoch 42/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.2085e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0029 - val_mean_absolute_error: 0.0417
# Epoch 43/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0372e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 44/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.0377e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0046 - val_mean_absolute_error: 0.0551
# Epoch 45/80
# 30/30 [==============================] - 1s 19ms/step - loss: 2.0996e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0059 - val_mean_absolute_error: 0.0660
# Epoch 46/80
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0220e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0033 - val_mean_absolute_error: 0.0476
# Epoch 47/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.9654e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0028 - val_mean_absolute_error: 0.0417
# Epoch 48/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8620e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0045 - val_mean_absolute_error: 0.0555
# Epoch 49/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.9440e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0045 - val_mean_absolute_error: 0.0556
# Epoch 50/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8977e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0027 - val_mean_absolute_error: 0.0424
# Epoch 51/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7757e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0052 - val_mean_absolute_error: 0.0603
# Epoch 52/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6925e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0042 - val_mean_absolute_error: 0.0533
# Epoch 53/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7658e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0032 - val_mean_absolute_error: 0.0464
# Epoch 54/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8852e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0034 - val_mean_absolute_error: 0.0474
# Epoch 55/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7812e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0040 - val_mean_absolute_error: 0.0536
# Epoch 56/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.7627e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0027 - val_mean_absolute_error: 0.0424
# Epoch 57/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.6952e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0024 - val_mean_absolute_error: 0.0399
# Epoch 58/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7082e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0033 - val_mean_absolute_error: 0.0463
# Epoch 59/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7098e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0041 - val_mean_absolute_error: 0.0546
# Epoch 60/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8376e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0030 - val_mean_absolute_error: 0.0448
# Epoch 61/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.7968e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0027 - val_mean_absolute_error: 0.0428
# Epoch 62/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5293e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0020 - val_mean_absolute_error: 0.0361
# Epoch 63/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.6415e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0027 - val_mean_absolute_error: 0.0427
# Epoch 64/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5872e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0027 - val_mean_absolute_error: 0.0422
# Epoch 65/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5350e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 66/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4585e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0031 - val_mean_absolute_error: 0.0474
# Epoch 67/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5899e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0037 - val_mean_absolute_error: 0.0514
# Epoch 68/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.5220e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0025 - val_mean_absolute_error: 0.0414
# Epoch 69/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4177e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0023 - val_mean_absolute_error: 0.0393
# Epoch 70/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5760e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0016 - val_mean_absolute_error: 0.0318
# Epoch 71/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4251e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0045 - val_mean_absolute_error: 0.0583
# Epoch 72/80
# 30/30 [==============================] - 1s 23ms/step - loss: 1.4396e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0038 - val_mean_absolute_error: 0.0534
# Epoch 73/80
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0023 - val_mean_absolute_error: 0.0393
# Epoch 74/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.3950e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 75/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.3798e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0033 - val_mean_absolute_error: 0.0475
# Epoch 76/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.4996e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 77/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.3018e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0034 - val_mean_absolute_error: 0.0490
# Epoch 78/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.3820e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0024 - val_mean_absolute_error: 0.0404
# Epoch 79/80
# 30/30 [==============================] - 1s 20ms/step - loss: 1.3733e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0035 - val_mean_absolute_error: 0.0502
# Epoch 80/80
# 30/30 [==============================] - 1s 19ms/step - loss: 1.2724e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0033 - val_mean_absolute_error: 0.0483

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 7ms/step
# array([[0.47928664, 0.48171854],
#        [0.4853836 , 0.48754293],
#        [0.49079275, 0.4926309 ],
#        [0.50597686, 0.5073542 ],
#        [0.5167166 , 0.5178734 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1559.5591, 1561.0483],
#        [1570.8623, 1571.8429],
#        [1580.8905, 1581.2726],
#        [1609.0406, 1608.5599],
#        [1628.9513, 1628.0555]], dtype=float32)

# %% [markdown]
# ## 3.7 Visualizing predicted and actual data

# %% [markdown]
# After fitting the data with our model we use it for prediction. We must use inverse transformation to get back the original value with the transformed function. Now we can use this data to visualize the prediction.

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1559.559082      1561.048340
# 2020-08-25  1582.07  1608.22     1570.862305      1571.842896
# 2020-08-26  1608.00  1652.38     1580.890503      1581.272583
# 2020-08-27  1653.68  1634.33     1609.040649      1608.559937
# 2020-08-28  1633.49  1644.41     1628.951294      1628.055542

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## 3.8 Predicting upcoming 10 days

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09':'2021-06-16']
# Out:
#                open    close open_predicted close_predicted
# 2021-06-09   2499.5   2491.4     2311.65332     2320.081787
# 2021-06-10  2494.01   2521.6    2319.184082     2328.494385
# 2021-06-11  2524.92  2513.93    2327.320068     2337.018555
# 2021-06-12      NaN      NaN            NaN             NaN
# 2021-06-13      NaN      NaN            NaN             NaN
# 2021-06-14      NaN      NaN            NaN             NaN
# 2021-06-15      NaN      NaN            NaN             NaN
# 2021-06-16      NaN      NaN            NaN             NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()

# %% [markdown]
# # Part 2

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# - Often wondered if we could know what would the price of bitcoin be 6 months from now or how would your favourite stocks look like in a week, now you can predict all of these with time series modelling.
#
# - One of the most commonly used data science applications is time series forecasting. As the name suggests, a time series forecast is predicting the future value of a variable by looking into the past history with the help of some additional features which are likely to affect those variables.
#
# - The algorithms are designed in such a way that it looks at the trends of the past and forecasts the future values.
#
# - There are dozens of algorithms which can do time series forecast. There are the basic ones like Auto Regression, Moving average, ARMA, ARIMA, simple exponential smoothing, Holt Winter’s method, linear regression to advanced ones like the multiple linear regression, LSTM (Long Short Term Memory), Artificial neural networks and many more.
#
# - Based on the data set and the supporting features we can make an informed decision and finalise the model.

# %% [markdown]
# # 2. Dataset

# %% [markdown]
# https://github.com/PacktPublishing/Learning-Pandas-Second-Edition/blob/master/data/goog.csv

# %% [markdown]
# # 3. Google Stock Prediction using ARIMA

# %% [markdown]
# ## 3.1 Importing libraries

# %%
import warnings       
warnings.filterwarnings('ignore')
import itertools
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 3.2 Loading data

# %%
df = pd.read_csv(r'C:\Users\HOME\Desktop\GOOG.csv', 
                 index_col=['date'], parse_dates=['date'])
df.head()
# Out:
#                           symbol   close    high       low    open   volume  \
# date
# 2016-06-14 00:00:00+00:00   GOOG  718.27  722.47  713.1200  716.48  1306065
# 2016-06-15 00:00:00+00:00   GOOG  718.92  722.98  717.3100  719.00  1214517
# 2016-06-16 00:00:00+00:00   GOOG  710.36  716.65  703.2600  714.91  1982471
# 2016-06-17 00:00:00+00:00   GOOG  691.72  708.82  688.4515  708.65  3402357
# 2016-06-20 00:00:00+00:00   GOOG  693.71  702.48  693.4100  698.77  2082538
#
#                            adjClose  adjHigh    adjLow  adjOpen  adjVolume  \
# date
# 2016-06-14 00:00:00+00:00    718.27   722.47  713.1200   716.48    1306065
# 2016-06-15 00:00:00+00:00    718.92   722.98  717.3100   719.00    1214517
# 2016-06-16 00:00:00+00:00    710.36   716.65  703.2600   714.91    1982471
# 2016-06-17 00:00:00+00:00    691.72   708.82  688.4515   708.65    3402357
# 2016-06-20 00:00:00+00:00    693.71   702.48  693.4100   698.77    2082538
#
#                            divCash  splitFactor
# date
# 2016-06-14 00:00:00+00:00      0.0          1.0
# 2016-06-15 00:00:00+00:00      0.0          1.0
# 2016-06-16 00:00:00+00:00      0.0          1.0
# 2016-06-17 00:00:00+00:00      0.0          1.0
# 2016-06-20 00:00:00+00:00      0.0          1.0

# %% [markdown]
# ## 3.3 Checking the data

# %%
#data size
df.shape
# Out:
# (1258, 13)

# %%
#N/A values
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## 3.4 Description of the data.

# %%
df['close'].plot(figsize=(20, 8), linewidth=1, label = 'Closing price');
plt.legend(fontsize = 15)

# %% [markdown]
# This time-series is definitely non-stationary, since it has a visible trend. We can confirm this hypothesis by using the Augmented Dickey-Fuller unit root test.

# %%
result = adfuller(df['close'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: 1.968587
# p-value: 0.998631
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# P-value is 1, so the null hypothesis about the presence of a unit root cannot be rejected.
#
# Let's see if can get rid of non-stationarity by taking the first difference.

# %%
diff1 = pd.Series(df['close'].diff()).dropna()
diff1.plot(figsize=(20, 8), label = '1st difference');
plt.legend(fontsize = 15)

# %%
result = adfuller(diff1)
print('ADF Statistic: %f' % result[0])
print('p-value: %e' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -7.734851
# p-value: 1.100607e-11
# Critical Values:
# 	1%: -3.436
# 	5%: -2.864
# 	10%: -2.568

# %% [markdown]
# P-value is close to zero, so the data is stationary.

# %%
#ACF and PACF of the initial data
plt.rcParams["figure.figsize"] = (15,6)
plot_acf(df.close);
plot_pacf(df.close);

# %%
#ACF and PACF of the first difference
plt.rcParams["figure.figsize"] = (15,6)
plot_acf(diff1);
plot_pacf(diff1);

# %% [markdown]
# ## 3.5 Building the model

# %%
df['close'].index = pd.DatetimeIndex(df['close'].index).to_period('D')
size = int(len(df) * 0.8)
train_df, test_df = df[0:size], df[size:len(df)]

# %%
#function for selecting the best model based on the Bayesian information criterion (BIC)
def select_mod(p_values, d_values, q_values, train):    
    mod_eval = []
    mod_eval = pd.DataFrame(mod_eval)
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    model = ARIMA(train, order=order)
                    model_fit = model.fit()
                    mod_eval = mod_eval.append({'Order':order, 'BIC':model_fit.bic}, 
                                               ignore_index=True)
                except:
                    continue
    return mod_eval

# %%
#ARIMA parameters
p = range(0, 2)
d = range(0, 2)
q = range(0, 2)
models = select_mod(p,d,q,train_df['close'])
models
# Out:
#        Order           BIC
# 0  (0, 0, 0)  13454.703614
# 1  (0, 0, 1)  12175.856858
# 2  (0, 1, 0)   8761.556850
# 3  (0, 1, 1)   8743.720969
# 4  (1, 0, 0)   8788.119458
# 5  (1, 0, 1)   8770.953605
# 6  (1, 1, 0)   8743.283549
# 7  (1, 1, 1)   8750.111911

# %%
#choosing the best model
print(models[models.BIC == models.BIC.min()])
# Out:
#        Order          BIC
# 6  (1, 1, 0)  8743.283549

# %%
model = ARIMA(train_df['close'], order=(0,1,0))
model_fit = model.fit()
resid = model_fit.resid
#evaluaring the residuals
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
resid.plot.kde();
plt.subplot(1, 2, 2)
resid.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
k2, p = stats.normaltest(resid)
print("p = {:g}".format(p))
# Out:
# p = 0

# %% [markdown]
# The residuals belong to a normal distribution

# %%
plt.rcParams["figure.figsize"] = (15,6)
plot_acf(resid);
plot_pacf(resid);

# %% [markdown]
# The residuals are not correlated and have zero mean, so the model is built adequately.

# %% [markdown]
# ## 3.6 Forecasting.

# %%
history = [x for x in train_df['close']]
predictions = list()
for t in range(len(test_df['close'])):
    model = ARIMA(history, order=(0,1,0))
    model_fit = model.fit()
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    history.append(test_df['close'][t])

# %%
#Root Mean Square Error
rmse = np.sqrt(mean_squared_error(test_df['close'], predictions))
#Mean Absolute Percentage Error
mape = np.round(np.mean(np.abs(test_df['close']-predictions)/test_df['close'])*100,2)
print('Test RMSE: %.3f' % rmse)
print('Test MAPE: %.3f' % mape)
# Out:
# Test RMSE: 32.096
# Test MAPE: 1.320

# %%
plt.figure(figsize=(20,10))
plt.plot(test_df['close'].index, test_df['close'], label = 'Actual values')
plt.plot(test_df['close'].index, predictions, color='red', label = 'Predicted values')
plt.legend(fontsize = 15)

# %%
plt.figure(figsize=(20,10))
plt.plot(train_df['close'].index, train_df['close'], 
         label = 'Training set')
plt.plot(test_df['close'].index, predictions, color='red', 
         label = 'Predicted values')
plt.legend(fontsize = 15)

# %% [markdown]
# ## 4.Conclusion
#
# In this Notebook, we explored LSTM and ARIMA and stock price using LSTM. We then visualized the opening and closing price value after using LSTM.
